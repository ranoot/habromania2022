# %%
import numpy as np
import math
import struct
import time
from enum import Enum
from matplotlib import pyplot as plt
import cv2 as cv
from random import sample

# %%
frame_org = cv.imread("frame.jpg")

# %% [markdown]
# Bisect the frame into equal chunks?
# Slice up the "frame" into another frame containing the black density values

# %%
crop_h = 30
b_crop_h = 0

frame = frame_org[crop_h:(frame_org.shape[0] - b_crop_h), :]

# %%
from skimage.util.shape import view_as_blocks

# %%
view_as_blocks()
